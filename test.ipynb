# %% [markdown]
# # Plot bug in GitLab

# %% [markdown]
# This notebook highlight situations where issue [32588](https://gitlab.com/gitlab-org/gitlab-ce/issues/32588) appears in GitLab.

# %%
# %matplotlib inline

import numpy as np
import matplotlib.pyplot as plt
import warnings

# %%
# This plot won't show because of the warning!
warnings.warn("Test")
plt.scatter(x=np.random.normal(size=100),
            y=np.random.normal(size=100));
# Out:
# /Users/jdecock/anaconda3/envs/cta/lib/python3.6/site-packages/ipykernel_launcher.py:2: UserWarning: Test

# %%
# This plot won't show because of the print!
print("Test")
plt.scatter(x=np.random.normal(size=100),
            y=np.random.normal(size=100));
# Out:
# Test

# %%
# This plot won't show because of the plt.scatter() return ("<matplotlib.collections.PathCollection at 0x120ad74e0>")!
plt.scatter(x=np.random.normal(size=100),
            y=np.random.normal(size=100))

# %%
# This one is OK
plt.scatter(x=np.random.normal(size=100),
            y=np.random.normal(size=100));
